# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train_data_2.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0            842     0          2.2         0   1.0     0.0         7.0
# 1           1021     1          0.5         1   0.0     1.0        53.0
# 2            563     1          0.5         1   2.0     1.0        41.0
# 3            615     1          2.5         0   0.0     0.0        10.0
# 4           1821     1          1.2         0  13.0     1.0        44.0
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.6      188.0      2.0  ...       20.0     756.0  2549.0   9.0   7.0
# 1    0.7      136.0      3.0  ...      905.0    1988.0  2631.0  17.0   3.0
# 2    0.9      145.0      5.0  ...     1263.0    1716.0  2603.0  11.0   2.0
# 3    0.8      131.0      6.0  ...     1216.0    1786.0  2769.0  16.0   8.0
# 4    0.6      141.0      2.0  ...     1208.0    1212.0  1411.0   8.0   2.0
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# ### Check The Clasees Frequency

# %%
## Checking the frequency for each class (Price range)
sns.histplot(data=df, x="price_range", bins=7, color='royalblue', alpha=0.7)
plt.title("Price Range Distribution")
plt.xlabel("Price Range")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Realtionship between battery_power and price_range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["battery_power"], x=df["price_range"])  
plt.title(f"Relationship between battery power and Price Range") 
plt.xticks([0,1,2,3])
plt.show()

# %% [markdown]
# ### Relationship betwen Beluetooth and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["blue"], x=df["price_range"])  
plt.title(f"Relationship between Bluetooth and Price Range") 
plt.xticks([0,1,2,3])
plt.yticks([0,1])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Relationship betwen Clock Speed and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["clock_speed"], x=df["price_range"])  
plt.title(f"Relationship between Clock Speed and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 14.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 14.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship betwen Dual SIM and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["dual_sim"], x=df["price_range"])  
plt.title(f"Relationship between Dual SIM and Price Range") 
plt.xticks([0,1,2,3])
plt.yticks([0,1])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Relationship betwen Front Camera megapixels and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["fc"], x=df["price_range"])  
plt.title(f"Relationship between Front Camera Megapixels and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 32.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 31.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 30.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship betwen 4G and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["four_g"], x=df["price_range"])  
plt.title(f"Relationship between 4G and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Relationship betwen Internal Memory in Gigabytes and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["int_memory"], x=df["price_range"])  
plt.title(f"Relationship between Internal Memory in Gigabytes and Price Range") 
plt.xticks([0,1,2,3])
plt.show()

# %% [markdown]
# ### Relationship between Mobile Depth in cm and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["m_dep"], x=df["price_range"])  
plt.title(f"Relationship between Mobile Depth in CM and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 40.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 39.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 39.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship between Weight of Mobile Phone and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["mobile_wt"], x=df["price_range"])  
plt.title(f"Relationship between Mobile Weight and Price Range") 
plt.xticks([0,1,2,3])
plt.show()

# %% [markdown]
# ### Relationship between Number of cores of the processor and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["n_cores"], x=df["price_range"])  
plt.title(f"Relationship between Number of Cores Of The processor and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 59.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship between Primary Camera megapixels and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["pc"], x=df["price_range"])  
plt.title(f"Relationship between Primary Camera megapixels and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship between Pixel Resolution Height and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["px_height"], x=df["price_range"])  
plt.title(f"Relationship between Pixel Resolution Height and Price Range") 
plt.xticks([0,1,2,3])
plt.show()

# %% [markdown]
# ### Relationship between Pixel Resolution width and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["px_width"], x=df["price_range"])  
plt.title(f"Relationship between Pixel Resolution width and Price Range") 
plt.xticks([0,1,2,3])
plt.show()

# %% [markdown]
# ### Relationship between RAM and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["ram"], x=df["price_range"])  
plt.title(f"Relationship between RAM and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 11.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Relationship between Screen Height of mobile in cm and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["sc_h"], x=df["price_range"])  
plt.title(f"Relationship between Screen Height of mobile in cm and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 25.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship between Screen Width of mobile in cm and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["sc_h"], x=df["price_range"])  
plt.title(f"Relationship between Screen Height of mobile in cm and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 25.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship between longest time that a single battery charge will last when you are and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["sc_w"], x=df["price_range"])  
plt.title(f"Relationship between Screen Width of mobile in cm and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 16.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Relationship between 3G and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["three_g"], x=df["price_range"])  
plt.title(f"Relationship between 3G and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Relationship between Touch Screen and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["touch_screen"], x=df["price_range"])  
plt.title(f"Relationship between Touch Screen and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Relationship between WIFI and Price Range

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(y=df["wifi"], x=df["price_range"])  
plt.title(f"Relationship between WIFI and Price Range") 
plt.xticks([0,1,2,3])
plt.show()
# Out:
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\yasme\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
